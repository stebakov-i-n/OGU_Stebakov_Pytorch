# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
# Вывод нескольких графиков на одном рисунке

fig, ax = plt.subplots(figsize=(10, 5))

ax.plot(np.random.randn((100)), c='r')
ax.plot(np.random.randn((100)), c='g'),

ax.legend(['Legend a', 'Legend b'])

ax.set_title('Title')

ax.set_xlabel('X label')
ax.set_ylabel('Y label')

plt.show()

# %%
# Применение логарифмической шкалы

fig, ax = plt.subplots(figsize=(10, 5))

ax.plot(np.random.rand((100)) + 0.5)

ax.set_yscale('log')

# %%
# Получение значения словаря по ключам

a = {'one': 1, 'two': 2}

a['one']
# Out:
# 1

# %%
# Формат хранения истории обучения

history = {'Tran loss': np.random.randn((100)) + 10,
           'Val loss': np.random.randn((100)) + 10,
           'Tran accuracy': np.random.randn((100)),
           'Val accuracy': np.random.randn((100))}

# %% [markdown]
# 1. Написать функцию для визуализации истории обучения. На двух отдельных рисунках должны быть графики для функции потерь и точности. Разным цветом обозначить train и val. Вывест легенду в формате ['Train', 'Val']. Заголовок не использовать. Подпись оси х Epochs. Подпись оси у подписать Loss или Accuracy. Сделать логарифмическую шкалу для графиков с функцией потерь.

# %%
def plot_history(history):
    ?

# %%
from mlxtend.plotting import plot_confusion_matrix # Вывод матрицы ошибок
from sklearn.metrics import confusion_matrix # Расчет матрицы ошибок
import torch

# %%
# Случайные метки классов и предсказания (не обработанные функцией SoftMax)
targets = torch.randint(0, 4, (100, ))
predictions = torch.randn(100, 4)

# %%
# Расчет матрицы ошибок

confusion_matrix(targets, targets)
# Out:
# array([[20,  0,  0,  0],
#        [ 0, 18,  0,  0],
#        [ 0,  0, 33,  0],
#        [ 0,  0,  0, 29]])

# %%
# Вывод матрицы ошибок

plot_confusion_matrix(confusion_matrix(targets, targets), figsize=(6, 4),cmap=plt.cm.Blues)
plt.show()

# %%
# Изменение подписей на шкале осей

plt.plot([0, 1, 2,  3], [0, 1, 2, 3])
plt.xticks([0, 1, 2, 3], ['1_x', '2_x', '3_x', '4_x'])
plt.yticks([0, 1, 2, 3], ['1_y', '2_y', '3_y', '4_y'])

plt.show()

# %% [markdown]
# 2. Написать функицию, которая будет выводить модифицированныую матрицу ошибок. Необходимо по предсказаниям определить предсказанные классы применив функцию SoftMax и argmax (см. Л.Р. № 5). Добавить заголовок, подписи классов на шкале.

# %%
def plot_cm(targets, predictions, title, classes):
    ?
